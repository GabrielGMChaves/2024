# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('C:/Users/bielz/OneDrive/Documentos/GitHub/2024/January/new dataset.xlsx')

# %%
data.head(10)
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend   900.0          2-Car  Non-incapacitating
# 4  2015      1    7  Weekend  1100.0          2-Car   No injury/unknown
# 5  2015      1    6  Weekday  1800.0          2-Car   No injury/unknown
# 6  2015      1    6  Weekday  1200.0          2-Car   No injury/unknown
# 7  2015      1    6  Weekday  1400.0          1-Car      Incapacitating
# 8  2015      1    7  Weekend  1400.0          2-Car   No injury/unknown
# 9  2015      1    7  Weekend  1600.0          1-Car   No injury/unknown
#
#                              Primary Factor        Reported_Location  \
# 0     OTHER (DRIVER) - EXPLAIN IN NARRATIVE               1ST & FESS
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates(inplace=True)

# %%
data['Weekend?']
# Out:
# 0        Weekday
# 1        Weekday
# 2        Weekend
# 3        Weekend
# 4        Weekend
#           ...
# 53938    Weekday
# 53939    Weekday
# 53940    Weekday
# 53941    Weekend
# 53942    Weekend
# Name: Weekend?, Length: 53879, dtype: object

# %%
data['Hour'] = pd.to_datetime(data['Hour'])

# %%
data
# Out:
#        Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0      2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1      2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2      2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
# 3      2015      1    7  Weekend   900.0          2-Car  Non-incapacitating
# 4      2015      1    7  Weekend  1100.0          2-Car   No injury/unknown
# ...     ...    ...  ...      ...     ...            ...                 ...
# 53938  2003     10    6  Weekday  1700.0          2-Car   No injury/unknown
# 53939  2003     11    3  Weekday   800.0          1-Car   No injury/unknown
# 53940  2003     12    5  Weekday  1200.0          2-Car   No injury/unknown
# 53941  2003     12    1  Weekend   700.0          2-Car   No injury/unknown
# 53942  2003     12    7  Weekend  1700.0          2-Car  Non-incapacitating
#
# ...

# %%
data.loc[1]
# Out:
# Year                                  2015
# Month                                    1
# Day                                      6
# Weekend?                           Weekday
# Hour                                1500.0
# Collision Type                       2-Car
# Injury Type              No injury/unknown
# Primary Factor       FOLLOWING TOO CLOSELY
# Reported_Location            2ND & COLLEGE
# Latitude                          39.16144
# Longitude                       -86.534848
# Name: 1, dtype: object

# %%
pd.to_datetime(data[['Year','Month','Day']])
# Out:
# 0       2015-01-05
# 1       2015-01-06
# 2       2015-01-06
# 3       2015-01-07
# 4       2015-01-07
#            ...
# 53938   2003-10-06
# 53939   2003-11-03
# 53940   2003-12-05
# 53941   2003-12-01
# 53942   2003-12-07
# Length: 53943, dtype: datetime64[ns]

# %%
data['Date'] = pd.to_datetime(data[['Year','Month','Day']])

# %%
data.head(2)
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type        Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car  No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car  No injury/unknown
#
#                           Primary Factor Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE        1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY     2ND & COLLEGE  39.161440
#
#    Longitude       Date
# 0 -86.525874 2015-01-05
# 1 -86.534848 2015-01-06

# %%
data = data.drop(['Year','Month','Day'], axis=1)

# %%
data.head(1)
# Out:
#   Weekend?  Hour Collision Type        Injury Type  \
# 0  Weekday   0.0          2-Car  No injury/unknown
#
#                           Primary Factor Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE        1ST & FESS  39.159207
#
#    Longitude       Date
# 0 -86.525874 2015-01-05

# %%
data['Hour'] = pd.to_datetime(data['Hour'],format='%H%M').dt.time
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 data['Hour'] = pd.to_datetime(data['Hour'],format='%H%M').dt.time
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# --> 250     cache_dates = convert_listlike(unique_dates, format)
# ...

# %%
try:
    data['Hour'] = pd.to_datetime(data['Hour'],format='%H%M').dt.time
except ValueError:
    data['Hour'] = pd.to_datetime('0000', format='%H%M').dt.time
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 try:
# ----> 2     data['Hour'] = pd.to_datetime(data['Hour'],format='%H%M').dt.time
#       3 except ValueError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     249 if len(unique_dates) < len(arg):
# --> 250     cache_dates = convert_listlike(unique_dates, format)
#     251     # GH#45319
#
# ...

# %%
data['Hour'] = data['Hour'].astype(int).astype(str).str.zfill(4)

# %%
data['Hour'] = data['Hour'].fillna(0)

# %%
data.head(1)
# Out:
#   Weekend?      Hour Collision Type        Injury Type  \
# 0  Weekday  00:00:00          2-Car  No injury/unknown
#
#                           Primary Factor Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE        1ST & FESS  39.159207
#
#    Longitude       Date
# 0 -86.525874 2015-01-05

# %%
try:
    data['Hour'] = pd.to_datetime(data['Hour'],format='%H%M').dt.time
except ValueError:
    data['Hour'] = pd.to_datetime('0000', format='%H%M').dt.time

# %%
data['Date'] = pd.to_datetime(data[['Hour','Date']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 data['Date'] = pd.to_datetime(data[['Hour','Date']])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1053, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1051         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1052 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1053     result = _assemble_from_unit_mappings(arg, errors, utc)
#    1054 elif isinstance(arg, Index):
#    1055     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1169, in _assemble_from_unit_mappings(arg, errors, utc)
#    1167 if len(req):
#    1168     _required = ",".join(req)
# -> 1169     raise ValueError(
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'] + ' ' + data['Hour'], format='%Y-%m-%d %H%M').dt.time
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 data['Date'] = pd.to_datetime(data['Date'] + ' ' + data['Hour'].astype(str).str.zfill(4), format='%Y-%m-%d %H%M').dt.time
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)
#     184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'].dt.year + data['Date'].dt.month + data['Date'].dt.day + data['Hour'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:128, in _evaluate_numexpr(op, op_str, a, b)
#     127 if result is None:
# --> 128     result = _evaluate_standard(op, op_str, a, b)
#     130 return result
#
# ...

# %%
#data['Date'].dt.day
#data['Date'].dt.year
#data['Date'].dt.month
data['Hour']
# Out:
# 0        00:00:00
# 1        15:00:00
# 2        23:00:00
# 3        09:00:00
# 4        11:00:00
#            ...
# 53938    17:00:00
# 53939    08:00:00
# 53940    12:00:00
# 53941    07:00:00
# 53942    17:00:00
# Name: Hour, Length: 53943, dtype: object

# %%
data['Year'] = data['Date'].dt.year
data['Month'] = data['Date'].dt.month
data['Day'] = data['Date'].dt.day
data.head(1)
# Out:
#   Weekend?      Hour Collision Type        Injury Type  \
# 0  Weekday  00:00:00          2-Car  No injury/unknown
#
#                           Primary Factor Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE        1ST & FESS  39.159207
#
#    Longitude       Date  Year  Month  Day
# 0 -86.525874 2015-01-05  2015      1    5

# %%
data['DateTime'] = pd.to_datetime(data[['Year','Month','Day','Hour']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\_libs\lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# TypeError: Invalid object type
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1206, in _assemble_from_unit_mappings(arg, errors, utc)
#    1205 try:
# -> 1206     values += to_timedelta(coerce(arg[value]), unit=u, errors=errors)
#    1207 except (TypeError, ValueError) as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1184, in _assemble_from_unit_mappings.<locals>.coerce(values)
#    1182 def coerce(values):
#    1183     # we allow coercion to if errors allows
# -> 1184     values = to_numeric(values, errors=errors)
# ...

# %%
data['Hours'] = data['Hour'].astype(str).str.zfill(4)

# %%
data.head(1)
# Out:
#   Weekend?      Hour Collision Type        Injury Type  \
# 0  Weekday  00:00:00          2-Car  No injury/unknown
#
#                           Primary Factor Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE        1ST & FESS  39.159207
#
#    Longitude       Date  Year  Month  Day     Hours
# 0 -86.525874 2015-01-05  2015      1    5  00:00:00

# %%
data['DateTime'] = pd.to_datetime(data[['Year','Month','Day','Hours']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\_libs\lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "15:00:00"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1206, in _assemble_from_unit_mappings(arg, errors, utc)
#    1205 try:
# -> 1206     values += to_timedelta(coerce(arg[value]), unit=u, errors=errors)
#    1207 except (TypeError, ValueError) as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1184, in _assemble_from_unit_mappings.<locals>.coerce(values)
#    1182 def coerce(values):
#    1183     # we allow coercion to if errors allows
# ...

# %%
data['Hours'] = data['Hours'].replace({'00:00:00': '0000'})

# %%
data.head(12)
# Out:
#    Weekend?      Hour Collision Type         Injury Type  \
# 0   Weekday  00:00:00          2-Car   No injury/unknown
# 1   Weekday  15:00:00          2-Car   No injury/unknown
# 2   Weekend  23:00:00          2-Car  Non-incapacitating
# 3   Weekend  09:00:00          2-Car  Non-incapacitating
# 4   Weekend  11:00:00          2-Car   No injury/unknown
# 5   Weekday  18:00:00          2-Car   No injury/unknown
# 6   Weekday  12:00:00          2-Car   No injury/unknown
# 7   Weekday  14:00:00          1-Car      Incapacitating
# 8   Weekend  14:00:00          2-Car   No injury/unknown
# 9   Weekend  16:00:00          1-Car   No injury/unknown
# 10  Weekend  15:00:00          2-Car   No injury/unknown
# 11  Weekend  16:00:00          2-Car   No injury/unknown
#
#                               Primary Factor        Reported_Location  \
# 0      OTHER (DRIVER) - EXPLAIN IN NARRATIVE               1ST & FESS
# 1                      FOLLOWING TOO CLOSELY            2ND & COLLEGE
# ...

# %%
data.drop('Hours')
data.head(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 data.drop('Hours')
#       2 data.head(1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
data.drop('Hours',axis=1)
# Out:
#       Weekend?      Hour Collision Type         Injury Type  \
# 0      Weekday  00:00:00          2-Car   No injury/unknown
# 1      Weekday  15:00:00          2-Car   No injury/unknown
# 2      Weekend  23:00:00          2-Car  Non-incapacitating
# 3      Weekend  09:00:00          2-Car  Non-incapacitating
# 4      Weekend  11:00:00          2-Car   No injury/unknown
# ...        ...       ...            ...                 ...
# 53938  Weekday  17:00:00          2-Car   No injury/unknown
# 53939  Weekday  08:00:00          1-Car   No injury/unknown
# 53940  Weekday  12:00:00          2-Car   No injury/unknown
# 53941  Weekend  07:00:00          2-Car   No injury/unknown
# 53942  Weekend  17:00:00          2-Car  Non-incapacitating
#
#                               Primary Factor      Reported_Location  \
# 0      OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS
# 1                      FOLLOWING TOO CLOSELY          2ND & COLLEGE
# ...

# %%
data.head(2)
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type        Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car  No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car  No injury/unknown
#
#                           Primary Factor Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE        1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY     2ND & COLLEGE  39.161440
#
#    Longitude
# 0 -86.525874
# 1 -86.534848

# %%
data.groupby('Year')

# %%
crashes_per_year = data['Year'].value_counts().reset_index()
crashes_per_year.columns = ['Year','Count']
crashes_per_year
# Out:
#     Year  Count
# 0   2003   4618
# 1   2008   4334
# 2   2015   4308
# 3   2004   4263
# 4   2012   4219
# 5   2014   4159
# 6   2010   4058
# 7   2013   4057
# 8   2007   4050
# 9   2009   4009
# 10  2005   3964
# 11  2006   3935
# 12  2011   3905

# %%
crashesYear = crashes_per_year

# %%
crashesYear
# Out:
#     Year  Count
# 0   2003   4618
# 1   2008   4334
# 2   2015   4308
# 3   2004   4263
# 4   2012   4219
# 5   2014   4159
# 6   2010   4058
# 7   2013   4057
# 8   2007   4050
# 9   2009   4009
# 10  2005   3964
# 11  2006   3935
# 12  2011   3905

# %%
crashesYear.sort_values(by='Year')
# Out:
#     Year  Count
# 0   2003   4618
# 3   2004   4263
# 10  2005   3964
# 11  2006   3935
# 8   2007   4050
# 1   2008   4334
# 9   2009   4009
# 6   2010   4058
# 12  2011   3905
# 4   2012   4219
# 7   2013   4057
# 5   2014   4159
# 2   2015   4308

# %%
crashesYear = crashesYear.sort_values(by='Year')

# %%
crashesYear
# Out:
#     Year  Count
# 0   2003   4618
# 3   2004   4263
# 10  2005   3964
# 11  2006   3935
# 8   2007   4050
# 1   2008   4334
# 9   2009   4009
# 6   2010   4058
# 12  2011   3905
# 4   2012   4219
# 7   2013   4057
# 5   2014   4159
# 2   2015   4308

# %%
plt.plot(crashesYear['Year'],crashesYear['Count'])
plt.xlabel('Year')
plt.ylabel('Number of crashes')
plt.title('Number of crashes per year')
plt.show()

# %%
data.head(3)
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
#
#    Longitude
# 0 -86.525874
# 1 -86.534848
# 2 -86.568890

# %%
crashTypes = data['Collision Type'].value_counts().reset_index()
crashTypes.columns = ['Collision Type','Count']
crashTypes
# Out:
#      Collision Type  Count
# 0             2-Car  37565
# 1             1-Car  10225
# 2           3+ Cars   3150
# 3  Moped/Motorcycle   1007
# 4               Bus    849
# 5        Pedestrian    609
# 6           Cyclist    468

# %%
plt.bar(crashTypes['Collision Type'], crashTypes['Count'])
plt.xlabel('Types of collision')
plt.xticks(rotation=45, fontsize=10)
plt.ylabel('Number of crashes')
plt.title('Types of collision - Visualization')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.head(3)
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
#
#    Longitude
# 0 -86.525874
# 1 -86.534848
# 2 -86.568890

# %%
crashLocations = data['Reported_Location'].value_counts().reset_index()
crashLocations.columns = ['Reported_Location', 'Count']
crashLocations10 = crashLocations.head(10)

# %%
crashLocations10
# Out:
#    Reported_Location  Count
# 0           E 3RD ST    374
# 1           W 3RD ST    222
# 2     SR37N & VERNAL    197
# 3             3RD ST    194
# 4        S WALNUT ST    172
# 5          E 10TH ST    152
# 6        N WALNUT ST    124
# 7  S COLLEGE MALL RD    123
# 8      SR37 & VERNAL    122
# 9          WALNUT ST    117

# %%
plt.bar(crashLocations10['Reported_Location'],crashLocations10['Count'])
plt.xticks(rotation=45)
plt.xlabel('Location')
plt.ylabel('Number of accidents')
plt.title('Top 10 Locations with the most crashes')
plt.show()

# %%
data.head(2)
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type        Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car  No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car  No injury/unknown
#
#                           Primary Factor Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE        1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY     2ND & COLLEGE  39.161440
#
#    Longitude   Hours
# 0 -86.525874    00.0
# 1 -86.534848  1500.0

# %%
data['Hours'] = data['Hour'].astype(str).str.zfill(4)
data.head(4)
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend   900.0          2-Car  Non-incapacitating
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
#
#    Longitude   Hours
# 0 -86.525874    00.0
# 1 -86.534848  1500.0
# 2 -86.568890  2300.0
# 3 -86.575956   900.0

# %%
data['Hour'] = data['Hour'].fillna(0)

# %%
data['Hours'] = data['Hour'].astype(str).str.zfill(4)

# %%
data.head(4)
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend   900.0          2-Car  Non-incapacitating
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
#
#    Longitude   Hours
# 0 -86.525874    00.0
# 1 -86.534848  1500.0
# 2 -86.568890  2300.0
# 3 -86.575956   900.0

# %%
data['Hours'] = data['Hour'].astype(int).astype(str).str.zfill(4)

# %%
data['Hours'] = pd.to_datetime(data['Hours'],format ='%H%M').dt.time

# %%
data.head(5)
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend   900.0          2-Car  Non-incapacitating
# 4  2015      1    7  Weekend  1100.0          2-Car   No injury/unknown
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
# 4          FAILURE TO YIELD RIGHT OF WAY                  W 3RD  39.164848
#
#    Longitude     Hours
# 0 -86.525874  00:00:00
# 1 -86.534848  15:00:00
# ...

# %%
crashesTime = data['Hours'].value_counts().reset_index()
crashesTime.columns = ['Hours','Count']

# %%
crashesTime
# Out:
#        Hours  Count
# 0   17:00:00   4630
# 1   16:00:00   4480
# 2   15:00:00   4280
# 3   12:00:00   3812
# 4   14:00:00   3746
# 5   13:00:00   3520
# 6   18:00:00   3225
# 7   11:00:00   3037
# 8   19:00:00   2439
# 9   10:00:00   2357
# 10  09:00:00   2317
# 11  08:00:00   2246
# 12  07:00:00   2030
# 13  20:00:00   1915
# 14  21:00:00   1793
# 15  22:00:00   1502
# 16  00:00:00   1338
# 17  23:00:00   1186
# 18  06:00:00    805
# 19  01:00:00    800
# 20  03:00:00    719
# 21  02:00:00    715
# 22  05:00:00    512
# 23  04:00:00    475

# %%
plt.bar(crashesTime['Hours'],crashesTime['Count'])
plt.xticks(rotation=45,fontsize=8)
plt.tight_layout()
plt.xlabel('Hours')
plt.ylabel('Nº of crashes')
plt.title('Crashes per time - Visualization')

plt.show()

# %%
crashesTime['Hours'] = crashesTime['Hours'].astype(str)
