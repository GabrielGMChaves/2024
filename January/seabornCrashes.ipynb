# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('C:/Users/bielz/OneDrive/Documentos/GitHub/2024/January/new dataset.xlsx')

# %%
data.head(3)
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
#
#    Longitude
# 0 -86.525874
# 1 -86.534848
# 2 -86.568890

# %%
data.duplicated().sum()
# Out:
# 64

# %%
data.drop_duplicates(inplace=True)

# %%
data.head(3)

# %%
data.head(3)

# %%
data['Hours'] = data['Hour'].astype(str).str.zfill(6)

# %%
data.head(3)
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
#
#    Longitude   Hours
# 0 -86.525874  0000.0
# 1 -86.534848  1500.0
# 2 -86.568890  2300.0

# %%
data.drop(columns=['Hours'], inplace=True)

# %%
data['Hours'] = pd.to_datetime(data['Hours'], format='%H%M').dt.time
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 data['Hours'] = pd.to_datetime(data['Hours'], format='%H%M').dt.time
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# --> 250     cache_dates = convert_listlike(unique_dates, format)
# ...

# %%
data['Hours'] = data['Hours'].str.rstrip('.0')

# %%
data.head()
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend   900.0          2-Car  Non-incapacitating
# 4  2015      1    7  Weekend  1100.0          2-Car   No injury/unknown
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
# 4          FAILURE TO YIELD RIGHT OF WAY                  W 3RD  39.164848
#
#    Longitude Hours
# 0 -86.525874
# 1 -86.534848    15
# 2 -86.568890    23
# ...

# %%
data['Hours'] = data['Hours'].fillna('0000')

# %%
data.head()
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend   900.0          2-Car  Non-incapacitating
# 4  2015      1    7  Weekend  1100.0          2-Car   No injury/unknown
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
# 4          FAILURE TO YIELD RIGHT OF WAY                  W 3RD  39.164848
#
#    Longitude Hours
# 0 -86.525874
# 1 -86.534848    15
# 2 -86.568890    23
# ...

# %%
data['Hours'].fillna('0000', inplace=True)

# %%
data['Hours'].replace(['', 'None', 'NaN', 'nan'], pd.NA, inplace=True)

# %%
data.head()
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend   900.0          2-Car  Non-incapacitating
# 4  2015      1    7  Weekend  1100.0          2-Car   No injury/unknown
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
# 4          FAILURE TO YIELD RIGHT OF WAY                  W 3RD  39.164848
#
#    Longitude   Hours
# 0 -86.525874    00.0
# 1 -86.534848  1500.0
# ...

# %%
data['Hours'] = data['Hour'].astype(str).str.zfill(6)
#data['Hours'] = data['Hours'].str.rstrip('.0')
#data['Hours'].replace(['', 'None', 'NaN', 'nan','0nan'], pd.NA, inplace=True)
#data['Hours'].fillna('00', inplace=True)
#data['Hours'] = data['Hours'] + '0000'

# %%
data.head()
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend   900.0          2-Car  Non-incapacitating
# 4  2015      1    7  Weekend  1100.0          2-Car   No injury/unknown
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
# 4          FAILURE TO YIELD RIGHT OF WAY                  W 3RD  39.164848
#
#    Longitude   Hours
# 0 -86.525874  000000
# 1 -86.534848  150000
# ...

# %%
data['Hours'] = pd.to_datetime(data['Hours'], format='%H%M').dt.time
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 data['Hours'] = pd.to_datetime(data['Hours'], format='%H%M%S').dt.time
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# --> 250     cache_dates = convert_listlike(unique_dates, format)
# ...

# %%
data.head()
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend   900.0          2-Car  Non-incapacitating
# 4  2015      1    7  Weekend  1100.0          2-Car   No injury/unknown
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
# 4          FAILURE TO YIELD RIGHT OF WAY                  W 3RD  39.164848
#
#    Longitude     Hours
# 0 -86.525874  00:00:00
# 1 -86.534848  00:15:00
# ...

# %%
data['Hours'] = pd.to_datetime(data['Hours'], format='%H%M%S')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 data['Hours'] = pd.to_datetime(data['Hours'], format='%H%M%S')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# --> 250     cache_dates = convert_listlike(unique_dates, format)
# ...

# %%
data.iloc[24]
# Out:
# Year                                     2015
# Month                                       1
# Day                                         2
# Weekend?                              Weekday
# Hour                                    700.0
# Collision Type                          1-Car
# Injury Type                 No injury/unknown
# Primary Factor       ANIMAL/OBJECT IN ROADWAY
# Reported_Location      3320 E RHORER & SNODDY
# Latitude                            39.121584
# Longitude                          -86.489744
# Hours                                    0700
# Name: 24, dtype: object

# %%
data['Hours'] = data['Hour'].astype(str).str.zfill(6)
data['Hours'] = data['Hours'].str.replace('.0', '')
data['Hours'].replace(['', 'None', 'NaN', 'nan','0nan'], pd.NA, inplace=True)
data['Hours'].fillna('0000', inplace=True)
#data['Hours'] = data['Hours'] + '0000'

# %%
data.head(26)
# Out:
#     Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0   2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1   2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2   2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
# 3   2015      1    7  Weekend   900.0          2-Car  Non-incapacitating
# 4   2015      1    7  Weekend  1100.0          2-Car   No injury/unknown
# 5   2015      1    6  Weekday  1800.0          2-Car   No injury/unknown
# 6   2015      1    6  Weekday  1200.0          2-Car   No injury/unknown
# 7   2015      1    6  Weekday  1400.0          1-Car      Incapacitating
# 8   2015      1    7  Weekend  1400.0          2-Car   No injury/unknown
# 9   2015      1    7  Weekend  1600.0          1-Car   No injury/unknown
# 10  2015      1    7  Weekend  1500.0          2-Car   No injury/unknown
# 11  2015      1    7  Weekend  1600.0          2-Car   No injury/unknown
# ...

# %%
data['Hours'] = pd.to_datetime(data['Hours'], format='%H%M').dt.time

# %%
data.head()
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend   900.0          2-Car  Non-incapacitating
# 4  2015      1    7  Weekend  1100.0          2-Car   No injury/unknown
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
# 4          FAILURE TO YIELD RIGHT OF WAY                  W 3RD  39.164848
#
#    Longitude     Hours
# 0 -86.525874  00:00:00
# 1 -86.534848  15:00:00
# ...

# %%
data['Hour'] = data['Hours']
data.drop(columns='Hours')
# Out:
#        Year  Month  Day Weekend?      Hour Collision Type         Injury Type  \
# 0      2015      1    5  Weekday  00:00:00          2-Car   No injury/unknown
# 1      2015      1    6  Weekday  15:00:00          2-Car   No injury/unknown
# 2      2015      1    6  Weekend  23:00:00          2-Car  Non-incapacitating
# 3      2015      1    7  Weekend  09:00:00          2-Car  Non-incapacitating
# 4      2015      1    7  Weekend  11:00:00          2-Car   No injury/unknown
# ...     ...    ...  ...      ...       ...            ...                 ...
# 53938  2003     10    6  Weekday  17:00:00          2-Car   No injury/unknown
# 53939  2003     11    3  Weekday  08:00:00          1-Car   No injury/unknown
# 53940  2003     12    5  Weekday  12:00:00          2-Car   No injury/unknown
# 53941  2003     12    1  Weekend  07:00:00          2-Car   No injury/unknown
# 53942  2003     12    7  Weekend  17:00:00          2-Car  Non-incapacitating
#
# ...

# %%
data['Date'] = pd.to_datetime(data[['Year','Month','Day']])

# %%
data.drop(columns = ['Year','Month','Day'])
# Out:
#       Weekend?      Hour Collision Type         Injury Type  \
# 0      Weekday  00:00:00          2-Car   No injury/unknown
# 1      Weekday  15:00:00          2-Car   No injury/unknown
# 2      Weekend  23:00:00          2-Car  Non-incapacitating
# 3      Weekend  09:00:00          2-Car  Non-incapacitating
# 4      Weekend  11:00:00          2-Car   No injury/unknown
# ...        ...       ...            ...                 ...
# 53938  Weekday  17:00:00          2-Car   No injury/unknown
# 53939  Weekday  08:00:00          1-Car   No injury/unknown
# 53940  Weekday  12:00:00          2-Car   No injury/unknown
# 53941  Weekend  07:00:00          2-Car   No injury/unknown
# 53942  Weekend  17:00:00          2-Car  Non-incapacitating
#
#                               Primary Factor      Reported_Location  \
# 0      OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS
# 1                      FOLLOWING TOO CLOSELY          2ND & COLLEGE
# ...

# %%
data.rename(columns={'Date'}, inplace=True)

# %%
data.head()
# Out:
#    Date  Month  Day Weekend?      Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday  00:00:00          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  15:00:00          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  23:00:00          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend  09:00:00          2-Car  Non-incapacitating
# 4  2015      1    7  Weekend  11:00:00          2-Car   No injury/unknown
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
# 4          FAILURE TO YIELD RIGHT OF WAY                  W 3RD  39.164848
#
#    Longitude     Hours       Date
# 0 -86.525874  00:00:00 2015-01-05
# ...

# %%
data['Dates'] = pd.to_datetime(data[['Date','Month','Day']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 data['Dates'] = pd.to_datetime(data[['Date','Month','Day']])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1053, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1051         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1052 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1053     result = _assemble_from_unit_mappings(arg, errors, utc)
#    1054 elif isinstance(arg, Index):
#    1055     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1148, in _assemble_from_unit_mappings(arg, errors, utc)
#    1146 arg = DataFrame(arg)
#    1147 if not arg.columns.is_unique:
# ...

# %%
data2 = data.iloc[:, :-1]

# %%
data2.head()
# Out:
#    Year  Month  Day Weekend?      Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday  00:00:00          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  15:00:00          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  23:00:00          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend  09:00:00          2-Car  Non-incapacitating
# 4  2015      1    7  Weekend  11:00:00          2-Car   No injury/unknown
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
# 4          FAILURE TO YIELD RIGHT OF WAY                  W 3RD  39.164848
#
#    Longitude     Hours
# 0 -86.525874  00:00:00
# ...

# %%
data['Dates'] = pd.to_datetime(data2[['Year','Month','Day']])

# %%
data2.rename(columns={'Date' : 'Year'}, inplace=True)

# %%
data.head()
# Out:
#    Date  Month  Day Weekend?      Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday  00:00:00          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  15:00:00          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  23:00:00          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend  09:00:00          2-Car  Non-incapacitating
# 4  2015      1    7  Weekend  11:00:00          2-Car   No injury/unknown
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
# 4          FAILURE TO YIELD RIGHT OF WAY                  W 3RD  39.164848
#
#    Longitude     Hours       Date      Dates
# ...

# %%
data = data2

# %%
data.head()
# Out:
#    Year  Month  Day Weekend?      Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday  00:00:00          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  15:00:00          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  23:00:00          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend  09:00:00          2-Car  Non-incapacitating
# 4  2015      1    7  Weekend  11:00:00          2-Car   No injury/unknown
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
# 4          FAILURE TO YIELD RIGHT OF WAY                  W 3RD  39.164848
#
#    Longitude     Hours
# 0 -86.525874  00:00:00
# ...

# %%
data['Date'] = pd.to_datetime(data2[['Year','Month','Day']])

# %%
data.head()
# Out:
#    Year  Month  Day Weekend?      Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday  00:00:00          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  15:00:00          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  23:00:00          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend  09:00:00          2-Car  Non-incapacitating
# 4  2015      1    7  Weekend  11:00:00          2-Car   No injury/unknown
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
# 4          FAILURE TO YIELD RIGHT OF WAY                  W 3RD  39.164848
#
#    Longitude     Hours       Date
# 0 -86.525874  00:00:00 2015-01-05
# ...

# %%
data['Year'] = data['Date']

# %%
data.drop(columns=['Month','Day','Date'], inplace=True)

# %%
data.head()
# Out:
#         Year Weekend?      Hour Collision Type         Injury Type  \
# 0 2015-01-05  Weekday  00:00:00          2-Car   No injury/unknown
# 1 2015-01-06  Weekday  15:00:00          2-Car   No injury/unknown
# 2 2015-01-06  Weekend  23:00:00          2-Car  Non-incapacitating
# 3 2015-01-07  Weekend  09:00:00          2-Car  Non-incapacitating
# 4 2015-01-07  Weekend  11:00:00          2-Car   No injury/unknown
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
# 4          FAILURE TO YIELD RIGHT OF WAY                  W 3RD  39.164848
#
#    Longitude     Hours
# 0 -86.525874  00:00:00
# 1 -86.534848  15:00:00
# 2 -86.568890  23:00:00
# ...

# %%
data.rename(columns={'Year':'Date'}, inplace =True)

# %%
data.head()
# Out:
#         Date Weekend?      Hour Collision Type         Injury Type  \
# 0 2015-01-05  Weekday  00:00:00          2-Car   No injury/unknown
# 1 2015-01-06  Weekday  15:00:00          2-Car   No injury/unknown
# 2 2015-01-06  Weekend  23:00:00          2-Car  Non-incapacitating
# 3 2015-01-07  Weekend  09:00:00          2-Car  Non-incapacitating
# 4 2015-01-07  Weekend  11:00:00          2-Car   No injury/unknown
#
#                           Primary Factor      Reported_Location   Latitude  \
# 0  OTHER (DRIVER) - EXPLAIN IN NARRATIVE             1ST & FESS  39.159207
# 1                  FOLLOWING TOO CLOSELY          2ND & COLLEGE  39.161440
# 2              DISREGARD SIGNAL/REG SIGN  BASSWOOD & BLOOMFIELD  39.149780
# 3          FAILURE TO YIELD RIGHT OF WAY         GATES & JACOBS  39.165655
# 4          FAILURE TO YIELD RIGHT OF WAY                  W 3RD  39.164848
#
#    Longitude     Hours
# 0 -86.525874  00:00:00
# 1 -86.534848  15:00:00
# 2 -86.568890  23:00:00
# ...

# %%
crashesYear = data['Date'].dt.year.value_counts().reset_index()
crashesYear.columns = ['Year','Count']
crashesYear = crashesYear.sort_values(by='Year')
crashesYear
# Out:
#     Year  Count
# 0   2003   4618
# 3   2004   4263
# 10  2005   3964
# 11  2006   3935
# 8   2007   4050
# 1   2008   4334
# 9   2009   4009
# 6   2010   4058
# 12  2011   3905
# 4   2012   4219
# 7   2013   4057
# 5   2014   4159
# 2   2015   4308

# %%
crashTypes = data['Collision Type'].value_counts().reset_index()
crashTypes.columns = ['Collision Type','Count']
crashTypes
# Out:
#      Collision Type  Count
# 0             2-Car  37565
# 1             1-Car  10225
# 2           3+ Cars   3150
# 3  Moped/Motorcycle   1007
# 4               Bus    849
# 5        Pedestrian    609
# 6           Cyclist    468

# %%
crashLocations = data['Reported_Location'].value_counts().reset_index()
crashLocations.columns = ['Reported_Location', 'Count']
crashLocations10 = crashLocations.head(10)
crashLocations10
# Out:
#    Reported_Location  Count
# 0           E 3RD ST    374
# 1           W 3RD ST    222
# 2     SR37N & VERNAL    197
# 3             3RD ST    194
# 4        S WALNUT ST    172
# 5          E 10TH ST    152
# 6        N WALNUT ST    124
# 7  S COLLEGE MALL RD    123
# 8      SR37 & VERNAL    122
# 9          WALNUT ST    117

# %%
crashesTime = data['Hours'].value_counts().reset_index()
crashesTime.columns = ['Hours','Count']
crashesTime
# Out:
#        Hours  Count
# 0   17:00:00   4630
# 1   16:00:00   4480
# 2   15:00:00   4280
# 3   12:00:00   3812
# 4   14:00:00   3746
# 5   13:00:00   3520
# 6   18:00:00   3225
# 7   11:00:00   3037
# 8   19:00:00   2439
# 9   10:00:00   2357
# 10  09:00:00   2317
# 11  08:00:00   2246
# 12  07:00:00   2030
# 13  20:00:00   1915
# 14  21:00:00   1793
# 15  22:00:00   1502
# 16  23:00:00   1186
# 17  00:00:00   1113
# 18  06:00:00    805
# 19  01:00:00    800
# 20  03:00:00    719
# 21  02:00:00    715
# 22  05:00:00    512
# 23  04:00:00    475

# %%
data['Date'].dt.time
# Out:
# 0        00:00:00
# 1        00:00:00
# 2        00:00:00
# 3        00:00:00
# 4        00:00:00
#            ...
# 53938    00:00:00
# 53939    00:00:00
# 53940    00:00:00
# 53941    00:00:00
# 53942    00:00:00
# Name: Date, Length: 53879, dtype: object

# %%
sb.barplot(x='Year',y='Count',data=crashesYear)
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
sb.barplot(x='Collision Type',y='Count',data=crashTypes)
plt.xlabel('Types of collision')
plt.xticks(rotation=45, fontsize=10)
plt.ylabel('Number of crashes')
plt.title('Types of collision - Visualization')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sb.barplot(x='Reported_Location',y='Count', data=crashLocations10)
plt.xticks(rotation=45)
plt.xlabel('Location')
plt.ylabel('Number of accidents')
plt.title('Top 10 Locations with the most crashes')
plt.show()

# %%
sb.barplot(x='Hours',y='Count',data=crashesTime)
plt.xticks(rotation=45,fontsize=8)
plt.tight_layout()
plt.xlabel('Hours')
plt.ylabel('Nº of crashes')
plt.title('Crashes per time - Visualization')
# Out:
# Text(0.5, 1.0, 'Crashes per time - Visualization')

# %%
data.head(100)
# Out:
#          Date Weekend?      Hour Collision Type         Injury Type  \
# 0  2015-01-05  Weekday  00:00:00          2-Car   No injury/unknown
# 1  2015-01-06  Weekday  15:00:00          2-Car   No injury/unknown
# 2  2015-01-06  Weekend  23:00:00          2-Car  Non-incapacitating
# 3  2015-01-07  Weekend  09:00:00          2-Car  Non-incapacitating
# 4  2015-01-07  Weekend  11:00:00          2-Car   No injury/unknown
# ..        ...      ...       ...            ...                 ...
# 95 2015-01-01  Weekend  11:00:00          1-Car  Non-incapacitating
# 96 2015-01-02  Weekday  08:00:00          1-Car   No injury/unknown
# 97 2015-01-03  Weekday  09:00:00          2-Car   No injury/unknown
# 98 2015-01-03  Weekday  11:00:00     Pedestrian  Non-incapacitating
# 99 2015-01-03  Weekday  13:00:00          2-Car   No injury/unknown
#
#                            Primary Factor      Reported_Location   Latitude  \
# ...
